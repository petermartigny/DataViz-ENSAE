# %%
import pandas as pd
pd.set_option('display.max_columns', False)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_excel('Data - Jeux Olympiques.xlsx', sep=';', sheetname='MainData')

# %%
data.head()
# Out:
#    Sort  Year      Sport     ...     Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0     1  1896  Athletics     ...             NaN         NaN         NaN
# 1     2  1896  Athletics     ...             NaN         NaN         NaN
# 2     3  1896  Athletics     ...             NaN         NaN         NaN
# 3     4  1896  Athletics     ...             NaN         NaN         NaN
# 4     5  1896  Athletics     ...             NaN         NaN         NaN
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['Sort', 'Year', 'Sport', 'Gender', 'Event', 'Athlete', 'Age', 'Result',
#        'Medal', 'City', 'Country', 'Team', 'Season', 'Team Medals', 'OR', 'WR',
#        'Notes', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32'],
#       dtype='object')

# %%
data.ix[:, :16]
# Out:
#         Sort  Year      Sport Gender ...   Season Team Medals        OR   WR
# 0          1  1896  Athletics      M ...   Summer         1.0   =ORS/OR  NaN
# 1          2  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 2          3  1896  Athletics      M ...   Summer         1.0       ORS  NaN
# 3          4  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 4          5  1896  Athletics      M ...   Summer         1.0        OR  NaN
# 5          6  1896  Athletics      M ...   Summer         1.0       ORS  NaN
# 6          7  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 7          8  1896  Athletics      M ...   Summer         1.0       ORS  NaN
# 8          9  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 9         10  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 10        11  1896  Athletics      M ...   Summer         1.0        OR  NaN
# 11        12  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 12        13  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 13        14  1896  Athletics      M ...   Summer         1.0        OB  NaN
# 14        15  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 15        16  1896  Athletics      M ...   Summer         1.0       NaN  NaN
# 16        17  1896  Athletics      M ...   Summer         1.0    ORS/OR  NaN
# 17        18  1896  Athletics      M ...   Summer         1.0       ORS  NaN
# 18        19  1896  Athletics      M ...   Summer         1.0       OR4  NaN
# 19        20  1896  Athletics      M ...   Summer         1.0       OR2  NaN
# 20        21  1896  Athletics      M ...   Summer         1.0       OR2  NaN
# 21        22  1896  Athletics      M ...   Summer         1.0        OR  NaN
# 22        23  1896  Athletics      M ...   Summer         1.0        OR  NaN
# 23        24  1896  Athletics      M ...   Summer         1.0        OR  NaN
# 24        25  1896  Athletics      M ...   Summer         1.0  =OR5/OR2  NaN
# 25        26  1896  Athletics      M ...   Summer         1.0       OR5  NaN
# 26        27  1896  Athletics      M ...   Summer         1.0      =OR3  NaN
# 27        28  1896  Athletics      M ...   Summer         1.0       OR3  NaN
# 28        29  1896  Athletics      M ...   Summer         1.0        OR  NaN
# 29        30  1896  Athletics      M ...   Summer         1.0        OR  NaN
# ...      ...   ...        ...    ... ...      ...         ...       ...  ...
# 39716  39717  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39717  39718  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39718  39719  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39719  39720  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39720  39721  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39721  39722  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39722  39723  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39723  39724  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39724  39725  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39725  39726  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39726  39727  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39727  39728  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39728  39729  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39729  39730  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39730  39731  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39731  39732  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39732  39733  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39733  39734  2016  Wrestling      F ...   Summer         1.0       NaN  NaN
# 39734  39735  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39735  39736  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39736  39737  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39737  39738  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39738  39739  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39739  39740  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39740  39741  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39741  39742  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39742  39743  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39743  39744  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39744  39745  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
# 39745  39746  2016  Wrestling      M ...   Summer         1.0       NaN  NaN
#
# [39746 rows x 16 columns]

# %%
data.Age = data.Age.fillna(data.Age.mean())

# %%
plt.boxplot(data['Age'], showfliers=False)
plt.show()

# %%
data.Country.value_counts()
# Out:
# United States    5391
# Great Britain    3624
# Australia        2919
# Greece           2626
# Germany          2235
# Canada           2108
# China            2058
# France           2055
# Brazil           2015
# Spain            1710
# Japan            1674
# Italy            1588
# South Korea      1577
# Soviet Union     1380
# Belgium          1292
# Mexico           1053
# Finland           897
# Sweden            891
# Netherlands       732
# Russia            610
# Norway            471
# Austria           395
# Switzerland       223
# Yugoslavia        222
# Name: Country, dtype: int64

# %%
sns.countplot(x="Age", data=data, palette="Greens_d");

# %%
sns.countplot(x="Country", data=data, palette="Greens_d", hue='Medal', orient='v');

# %%
data['Medal'] = data['Medal'].apply(lambda x: x.lower())

# %%
sns.countplot(y="Team", data=data[data.Year == 2016], palette="Greens_d", hue='Medal', orient='v');

# %%
sns.barplot(data.Team.value_counts().values[:10], data.Team.value_counts().index[:10])
plt.show()
