# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', False)
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import seaborn as sns

# %%
data = pd.read_excel('Data - Jeux Olympiques.xlsx', sep=';', sheetname='MainData')
# Clean medal column
data['Medal'] = data['Medal'].apply(lambda x: x.lower())

# %%
data.head()
# Out:
#    Sort  Year      Sport     ...     Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0     1  1896  Athletics     ...             NaN         NaN         NaN
# 1     2  1896  Athletics     ...             NaN         NaN         NaN
# 2     3  1896  Athletics     ...             NaN         NaN         NaN
# 3     4  1896  Athletics     ...             NaN         NaN         NaN
# 4     5  1896  Athletics     ...             NaN         NaN         NaN
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['Sort', 'Year', 'Sport', 'Gender', 'Event', 'Athlete', 'Age', 'Result',
#        'Medal', 'City', 'Country', 'Team', 'Season', 'Team Medals', 'OR', 'WR',
#        'Notes', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32'],
#       dtype='object')

# %%
data = data.ix[:, :16]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39746 entries, 0 to 39745
# Data columns (total 16 columns):
# Sort           39746 non-null int64
# Year           39746 non-null int64
# Sport          39746 non-null object
# Gender         39746 non-null object
# Event          39746 non-null object
# Athlete        39746 non-null object
# Age            39333 non-null float64
# Result         22973 non-null object
# Medal          39746 non-null object
# City           39746 non-null object
# Country        39746 non-null object
# Team           39746 non-null object
# Season         39745 non-null object
# Team Medals    39738 non-null float64
# OR             3231 non-null object
# WR             1043 non-null object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 4.9+ MB

# %% [markdown]
# #### Age

# %%
# Fill missing values for age with the mean age
data.Age = data.Age.fillna(data.Age.mean())
plt.boxplot(data['Age'], showfliers=False)
plt.title('Boxplot of Ages')
plt.show()
sns.distplot(data.Age)
plt.title('Distribution of Ages')
plt.show()

sns.countplot(x="Age", data=data, palette="Greens_d")
plt.title('Distribution of Ages')
plt.show()

# %% [markdown]
# #### Year

# %%
sns.distplot(data.Year, bins=60)
plt.show()

# %% [markdown]
# #### Year histogram by season

# %%
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.charts import Histogram

hist = Histogram(data, values="Year", color="Season", legend="top_right", bins=50)
show(hist)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6734bcc6-bc81-4c86-95d9-ff37a98e1d42">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="6d2f7708-7ce1-4edf-bf18-30bdde8ad490"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6d2f7708-7ce1-4edf-bf18-30bdde8ad490").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6d2f7708-7ce1-4edf-bf18-30bdde8ad490");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6d2f7708-7ce1-4edf-bf18-30bdde8ad490' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b5f87d6e-9c29-41a8-b118-41a0dd95dc16":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7cac28ad-e245-4eee-94af-f915282fad2a","type":"PanTool"},{"id":"3e179cea-002c-4ab3-bfca-6b1773cfde86","type":"WheelZoomTool"},{"id":"01946e54-b386-4e0a-a1d6-c7a720887721","type":"BoxZoomTool"},{"id":"9e05c245-7559-48aa-8424-255801cb2dd8","type":"SaveTool"},{"id":"6d597e9f-5abf-49ca-90ab-227b2dd339c0","type":"ResetTool"},{"id":"8de5a471-93ac-42c9-94a7-8371e6e95e7e","type":"HelpTool"}]},"id":"2d1a8136-0183-471d-895f-02b96eb1af08","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f0d2ef09-8af7-408f-98cb-6df74569c5dd","type":"Rect"},{"attributes":{"data_source":{"id":"6d72d064-03a7-48e1-9683-d957a148969b","type":"ColumnDataSource"},"glyph":{"id":"93b5cdec-20f6-476d-b60c-b5e741dcea42","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"85a32a4f-ff73-44ab-a5a4-8cd85c95f9b9","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"428b781f-3d42-4c1c-97d6-c2b5300a2b9a","type":"Rect"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1990.6, 1992.4]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[321.0],"label":["(1990.6, 1992.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.800000000000182],"x":["1991.5"],"y":[160.5]}},"id":"b610864c-c6bd-4516-9727-f09d204f5374","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8c722911-3b7d-4a62-8fd9-897c5a5826f9","type":"ColumnDataSource"},"glyph":{"id":"428b781f-3d42-4c1c-97d6-c2b5300a2b9a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"eaa1fd8f-810f-45a1-99da-b5a19b8f25b6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1947.4, 1949.2]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[134.0],"label":["(1947.4, 1949.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.7999999999999545],"x":["1948.3000000000002"],"y":[67.0]}},"id":"13f66c36-c47a-42ca-a601-86997a9d07a8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1970.8, 1972.6]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[198.0],"label":["(1970.8, 1972.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.7999999999999545],"x":["1971.6999999999998"],"y":[99.0]}},"id":"1fcefaf2-f96c-4350-a51f-06c06be5739a","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"001658d9-1d51-4af1-99c2-ab0361a989c9","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1997.8, 1999.6]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[448.0],"label":["(1997.8, 1999.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.7999999999999545],"x":["1998.6999999999998"],"y":[224.0]}},"id":"7acf1f89-5a6f-4cec-b7ab-39c17bd5c3b9","type":"ColumnDataSource"},{"attributes":{"data_source" ...

# %% [markdown]
# #### Year histogram by gender

# %%
hist = Histogram(data, values="Year", color="Gender", legend="top_right", bins=50)
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="bfb7eb9e-255b-4d74-889c-83e43ab4681c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#bfb7eb9e-255b-4d74-889c-83e43ab4681c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bfb7eb9e-255b-4d74-889c-83e43ab4681c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bfb7eb9e-255b-4d74-889c-83e43ab4681c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d8341e8d-7a4c-4cff-bd89-d7ea465e5c6d":{"roots":{"references":[{"attributes":{"data_source":{"id":"7dc149ac-1330-4131-88e5-0f58f7d0538f","type":"ColumnDataSource"},"glyph":{"id":"4d0b6726-75d8-46fe-b101-f9f38f7f7f46","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"974e131a-63c9-4bfa-8d96-dc60fe786697","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1934.4, 1936.8]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[922.0],"label":["(1934.4, 1936.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.3999999999998636],"x":["1935.6"],"y":[461.0]}},"id":"6d0e3cfd-97cf-48c5-970c-e2643e23c3cb","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5e3924e3-1681-40f4-9d28-557376c2fb2a","type":"ColumnDataSource"},"glyph":{"id":"2c545658-4798-4772-ab62-bb6657d5ff3c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8546e503-f154-46f1-9f7a-43024da237b9","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"1f2064ee-8a51-40e8-b729-dd820dcebb2d","subtype":"Chart","type":"Plot"}},"id":"ccd43b73-e989-463b-9522-1ef2f95a498f","type":"ResetTool"},{"attributes":{"data_source":{"id":"3e16ae4b-232b-450e-b96e-939b3038c393","type":"ColumnDataSource"},"glyph":{"id":"7c51bee0-6e1d-4eb4-b7ef-34d61d2f1f7a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6e3a00d7-5757-47e5-b7e2-a1af5609845e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"81bffbd4-32aa-4c3e-83d7-09078564c1ed","type":"Rect"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1907.0, 1909.3]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[15.0],"label":["(1907.0, 1909.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.3199999999999363],"x":["1908.15"],"y":[7.5]}},"id":"695b1a3b-ceaa-4e14-af07-73bea003815d","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"1f2064ee-8a51-40e8-b729-dd820dcebb2d","subtype":"Chart","type":"Plot"}},"id":"7785f719-78f4-40e4-8214-0424da568b3a","type":"SaveTool"},{"attributes":{"data_source":{"id":"226fd305-72c0-4831-ab00-a24b27520c19","type":"ColumnDataSource"},"glyph":{"id":"aed6adc9-345b-450e-a907-06a6a7d60d9d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e9a8514a-3bbb-4e2f-9ef4-08b5a879f89b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(2011.4, 2013.7]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[920.0],"label":["(2011.4, 2013.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.3200000000001637],"x":["2012.5500000000002"],"y":[460.0]}},"id":"c57f0ce0-72a8-4b62-b260-79ba090d5cf8","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":2113.8102499999995,"start":1798.19975},"id":"1ee321de-b6a3-41e5-beb8-22de65ed5952","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aac45e6e-aa9b-47a3-9ed8-23c5512a2ce0","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0eb31785-363d-407a-8687-d38116f8d103","type":"Rect"},{"attributes":{"data_source":{"i ...

# %%
data.Medal.value_counts()
# Out:
# gold      13356
# bronze    13304
# silver    13086
# Name: Medal, dtype: int64

# %%
aux = data.Country.value_counts()
sns.barplot(y=aux.index, x=aux.values)
plt.title('Countries that have hosted most Olympic games')
plt.show()

# %%
aux = data.City.value_counts()[:20]
sns.barplot(y=aux.index, x=aux.values)
plt.title('Cities that have hosted most Olympic games')
plt.show()

# %%
aux = data[data.Season == 'Winter'].sort_values('Year').assign(x=1).groupby('Year')['x'].sum()
sns.barplot(x=aux.index, y=aux.values)
plt.title('Number of medals in Winter Olympic games')
plt.show()

aux = data[data.Season == 'Summer'].sort_values('Year').assign(x=1).groupby('Year')['x'].sum()
sns.barplot(x=aux.index, y=aux.values)
plt.title('Number of medals in Summer Olympic games')
plt.show()

# %%
aux = data.Athlete.value_counts()[:10]
sns.barplot(y=aux.index, x=aux.values)
plt.title('Number of medals in Summer Olympic games')
plt.show()

# %%
data[data.Country == 'France']
# Out:
#         Sort  Year          Sport  ...  Team Medals       OR    WR
# 151      152  1900        Archery  ...          1.0      NaN   NaN
# 152      153  1900        Archery  ...          1.0      NaN   NaN
# 153      154  1900        Archery  ...          1.0      NaN   NaN
# 154      155  1900        Archery  ...          1.0      NaN   NaN
# 155      156  1900        Archery  ...          1.0      NaN   NaN
# 156      157  1900        Archery  ...          1.0      NaN   NaN
# 157      158  1900        Archery  ...          1.0      NaN   NaN
# 158      159  1900        Archery  ...          1.0      NaN   NaN
# 159      160  1900        Archery  ...          1.0      NaN   NaN
# 160      161  1900        Archery  ...          1.0       OR   NaN
# 161      162  1900        Archery  ...          1.0      NaN   NaN
# 162      163  1900        Archery  ...          1.0      NaN   NaN
# 163      164  1900        Archery  ...          1.0       OR   NaN
# 164      165  1900        Archery  ...          1.0      NaN   NaN
# 165      166  1900        Archery  ...          1.0      NaN   NaN
# 166      167  1900        Archery  ...          1.0      NaN   NaN
# 167      168  1900        Archery  ...          1.0      NaN   NaN
# 168      169  1900        Archery  ...          1.0      NaN   NaN
# 169      170  1900        Archery  ...          1.0      NaN   NaN
# 170      171  1900        Archery  ...          1.0      NaN   NaN
# 171      172  1900      Athletics  ...          1.0  ORS/=OR    WR
# 172      173  1900      Athletics  ...          1.0      NaN   NaN
# 173      174  1900      Athletics  ...          1.0      NaN   NaN
# 174      175  1900      Athletics  ...          1.0       OR  =WRS
# 175      176  1900      Athletics  ...          1.0     =ORS  =WRS
# 176      177  1900      Athletics  ...          1.0      NaN   NaN
# 177      178  1900      Athletics  ...          1.0       OR   NaN
# 178      179  1900      Athletics  ...          1.0      NaN   NaN
# 179      180  1900      Athletics  ...          1.0      NaN   NaN
# 180      181  1900      Athletics  ...          1.0   ORS/OR   NaN
# ...      ...   ...            ...  ...          ...      ...   ...
# 24476  24477  1992  Speed Skating  ...          1.0      NaN   NaN
# 24477  24478  1992  Speed Skating  ...          1.0      NaN   NaN
# 24478  24479  1992  Speed Skating  ...          1.0      NaN   NaN
# 24479  24480  1992  Speed Skating  ...          1.0      NaN   NaN
# 24480  24481  1992  Speed Skating  ...          1.0      NaN   NaN
# 24481  24482  1992  Speed Skating  ...          1.0      NaN   NaN
# 24482  24483  1992  Speed Skating  ...          1.0      NaN   NaN
# 24483  24484  1992  Speed Skating  ...          1.0      NaN   NaN
# 24484  24485  1992  Speed Skating  ...          1.0      NaN   NaN
# 24485  24486  1992  Speed Skating  ...          1.0      NaN   NaN
# 24486  24487  1992  Speed Skating  ...          1.0      NaN   NaN
# 24487  24488  1992  Speed Skating  ...          1.0      NaN   NaN
# 24488  24489  1992  Speed Skating  ...          1.0      NaN   NaN
# 24489  24490  1992  Speed Skating  ...          1.0      NaN   NaN
# 24490  24491  1992  Speed Skating  ...          1.0      NaN   NaN
# 24491  24492  1992  Speed Skating  ...          1.0      NaN   NaN
# 24492  24493  1992  Speed Skating  ...          1.0      NaN   NaN
# 24493  24494  1992  Speed Skating  ...          1.0      NaN   NaN
# 24494  24495  1992  Speed Skating  ...          1.0      NaN   NaN
# 24495  24496  1992  Speed Skating  ...          1.0      NaN   NaN
# 24496  24497  1992  Speed Skating  ...          1.0      NaN   NaN
# 24497  24498  1992  Speed Skating  ...          1.0      NaN   NaN
# 24498  24499  1992  Speed Skating  ...          1.0      NaN   NaN
# 24499  24500  1992  Speed Skating  ...          1.0      NaN   NaN
# 24500  24501  1992  Speed Skating  ...          1.0      NaN   NaN
# 24501  24502  1992  Speed Skating  ...          1.0      NaN   NaN
# 24502  24503  1992  Speed Skating  ...          1.0      NaN   NaN
# 24503  24504  1992  Speed Skating  ...          1.0      NaN   NaN
# 24504  24505  1992  Speed Skating  ...          1.0      NaN   NaN
# 24505  24506  1992  Speed Skating  ...          1.0      NaN   NaN
#
# [2055 rows x 16 columns]

# %%
hist = Histogram(data[data.Country == 'France'], values="Year", color="Season", legend="top_right", bins=50)
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a9a9c1d5-9bcd-4906-8e90-9be180887ff8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a9a9c1d5-9bcd-4906-8e90-9be180887ff8").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a9a9c1d5-9bcd-4906-8e90-9be180887ff8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a9a9c1d5-9bcd-4906-8e90-9be180887ff8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"457ee84f-09ec-4dc0-a88d-1f98a541dc9b":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ca2e62b6-28b7-43a8-b032-10dfa31594ac","type":"Rect"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1922.1, 1922.6]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[0.0],"label":["(1922.1, 1922.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.4800000000000182],"x":["1922.35"],"y":[0.0]}},"id":"3304e707-af98-470d-a69c-259e39bdd2f8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f2c68532-34fa-4031-96ac-fc784943be83","type":"ColumnDataSource"},"glyph":{"id":"430e52bc-ab2d-40af-9e0c-260002c0d55d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"438507e9-68c9-4945-aa78-364eeca5d75d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a8b6d95a-0445-4dec-bf03-36a154a019e5","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"25e8dd97-3ece-46d8-8211-4cb4a022c21e","type":"Rect"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1989.3, 1990.6]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(1989.3, 1990.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.3600000000001273],"x":["1989.9499999999998"],"y":[0.0]}},"id":"bf6402ce-125e-4105-ba47-9bff6a0dff7a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"62b94e90-dafc-4ea4-883c-edf4ed6a53f3","type":"ColumnDataSource"},"glyph":{"id":"3110c1a5-cd3e-4040-a65f-226604c59c4d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"17060ef0-216d-40a4-aee5-32443ea6884e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["height","y","line_alpha","fill_alpha","label","width","x","color","line_color"],"data":{"chart_index":["(1941.7, 1943.0]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(1941.7, 1943.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.3599999999999],"x":["1942.35"],"y":[0.0]}},"id":"b1e63897-e411-4724-8661-de6d5e63df5f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"634ee418-5949-435f-bd79-0c443b6a11e7","type":"Rect"},{"attributes":{"data_source":{"id":"879d01f5-ca8b-4ff5-8962-3c1b6327f3b3","type":"ColumnDataSource"},"glyph":{"id":"608742cb-ca8f-4ee1-bfa6-9a3e3fd8602b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2e3c1359-4ec0-499a-866f-dd0beecd6e17","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"98fc8a9c-80d5-4db2-8a8e-f8004953aa92","type":"ColumnDataSource"},"glyph":{"id":"6855675e-1e80-4e87-9174-7ce32ac40654","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"33b5e5d0-29f1-4b29-ad9c-ff53c7e1b91a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6b1917c4-8e6f-4d77-bdcf-1bea1cfec912","type":"ColumnDataSource"},"glyph":{"id":"627286e4-c4f1-4a09-86c0-2bd45cd0511a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":nul ...

# %%
data[(data.Country == 'France') & (data.Year > 1940)].Season.value_counts()
# Out:
# Winter    520
# Name: Season, dtype: int64

# %%
data.columns
# Out:
# Index(['Sort', 'Year', 'Sport', 'Gender', 'Event', 'Athlete', 'Age', 'Result',
#        'Medal', 'City', 'Country', 'Team', 'Season', 'Team Medals', 'OR',
#        'WR'],
#       dtype='object')

# %%
data.Country.value_counts()
# Out:
# United States    5391
# Great Britain    3624
# Australia        2919
# Greece           2626
# Germany          2235
# Canada           2108
# China            2058
# France           2055
# Brazil           2015
# Spain            1710
# Japan            1674
# Italy            1588
# South Korea      1577
# Soviet Union     1380
# Belgium          1292
# Mexico           1053
# Finland           897
# Sweden            891
# Netherlands       732
# Russia            610
# Norway            471
# Austria           395
# Switzerland       223
# Yugoslavia        222
# Name: Country, dtype: int64

# %%
sns.countplot(x="Country", data=data, palette="Greens_d", hue='Medal', orient='v');

# %%
sns.countplot(y="Team", data=data[data.Year == 2016], palette="Greens_d", hue='Medal', orient='v');

# %%
sns.barplot(data.Team.value_counts().values[:10], data.Team.value_counts().index[:10])
plt.show()
